# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np
import torch
import random
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# select this option to load version 1 (with a single agent) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726624e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %%
from ddpg_agent_multi import Agent

agent = Agent(state_size=state_size, action_size=action_size, random_seed=2, agent_size=num_agents)

# %%
# Train the Agent

def ddpg(n_episodes=1000, max_t=1000, print_every=100):
    """Deep Deterministic Policy Gradients DDPG  from Pendulum exercise was employed: 
       Params:
            n_episodes (int): maximum number of training episodes
            max_t (int): maximum number of timesteps per episode
            print_every(int): print update 
    """
    scores_deque = deque(maxlen=print_every)
    scores = [] # list containing scores from each episode
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name] # reset the environment
        states = env_info.vector_observations # get the current state
        #print('states= ', states.shape)
        agent.reset() #initialize agents 
        ascores = np.zeros(num_agents) 
        for t in range(max_t):
            actions=[] # clear actions
            actions = agent.act(states) # select an action   
            #print('actions= ',np.array(actions).shape)
            action_info = env.step(actions)[brain_name] # get enviroment info
            next_states = action_info.vector_observations # get next state (for each agent)
            #print('next states= ', next_states.shape)
            rewards = action_info.rewards # get reward (for each agent)
            #print('rewards= ', np.array(rewards).shape)
            dones = action_info.local_done # see if episode finished
            #print('dones= ', np.array(dones).shape) 
            # Save experiences / rewards :
            for index in range(0,num_agents):
                agent.save_experience(states[index], actions[index], rewards[index], next_states[index], dones[index])
            agent.multi_step(t) #Train each agent 
            states = next_states # roll over states to next time step
            #print('second states= ',states)
            ascores += rewards # update the score (for each agent)
            #print('scores= ', np.array(ascores).shape)

            if np.any(dones):
                break 
 
        scores_deque.append(np.mean(ascores))
        scores.append(np.mean(ascores))         # save most recent score
        if i_episode % 1 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="\n")   
        torch.save(agent.actor_local.state_dict(),  'checkpoint_actor.pth' )
        torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        if np.mean(scores_deque)>=30.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_deque)))
            break
            
    return scores

scores = ddpg()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1	Average Score: 0.62
# Episode 2	Average Score: 0.61
# Episode 3	Average Score: 0.52
# Episode 4	Average Score: 0.49
# Episode 5	Average Score: 0.51
# Episode 6	Average Score: 0.49
# Episode 7	Average Score: 0.53
# Episode 8	Average Score: 0.55
# Episode 9	Average Score: 0.60
# Episode 10	Average Score: 0.61
# Episode 11	Average Score: 0.62
# Episode 12	Average Score: 0.63
# Episode 13	Average Score: 0.68
# Episode 14	Average Score: 0.72
# Episode 15	Average Score: 0.77
# Episode 16	Average Score: 0.81
# Episode 17	Average Score: 0.84
# Episode 18	Average Score: 0.88
# Episode 19	Average Score: 0.89
# Episode 20	Average Score: 0.90
# Episode 21	Average Score: 0.90
# Episode 22	Average Score: 0.92
# Episode 23	Average Score: 0.95
# Episode 24	Average Score: 0.98
# Episode 25	Average Score: 1.00
# Episode 26	Average Score: 1.03
# Episode 27	Average Score: 1.05
# Episode 28	Average Score: 1.08
# Episode 29	Average Score: 1.11
# Episode 30	Average Score: 1.15
# Episode 31	Average Score: 1.18
# Episode 32	Average Score: 1.21
# Episode 33	Average Score: 1.25
# Episode 34	Average Score: 1.30
# Episode 35	Average Score: 1.34
# Episode 36	Average Score: 1.40
# Episode 37	Average Score: 1.44
# Episode 38	Average Score: 1.47
# Episode 39	Average Score: 1.52
# Episode 40	Average Score: 1.58
# Episode 41	Average Score: 1.61
# Episode 42	Average Score: 1.66
# Episode 43	Average Score: 1.71
# Episode 44	Average Score: 1.75
# Episode 45	Average Score: 1.79
# Episode 46	Average Score: 1.83
# Episode 47	Average Score: 1.87
# Episode 48	Average Score: 1.89
# Episode 49	Average Score: 1.92
# Episode 50	Average Score: 1.97
# Episode 51	Average Score: 2.01
# Episode 52	Average Score: 2.07
# Episode 53	Average Score: 2.11
# Episode 54	Average Score: 2.16
# Episode 55	Average Score: 2.21
# Episode 56	Average Score: 2.26
# Episode 57	Average Score: 2.31
# Episode 58	Average Score: 2.37
# Episode 59	Average Score: 2.43
# Episode 60	Average Score: 2.49
# Episode 61	Average Score: 2.60
# Episode 62	Average Score: 2.68
# Episode 63	Average Score: 2.75
# Episode 64	Average Score: 2.84
# Episode 65	Average Score: 2.91
# Episode 66	Average Score: 2.98
# Episode 67	Average Score: 3.08
# Episode 68	Average Score: 3.17
# Episode 69	Average Score: 3.26
# Episode 70	Average Score: 3.35
# Episode 71	Average Score: 3.45
# Episode 72	Average Score: 3.56
# Episode 73	Average Score: 3.64
# Episode 74	Average Score: 3.71
# Episode 75	Average Score: 3.79
# Episode 76	Average Score: 3.87
# Episode 77	Average Score: 3.95
# Episode 78	Average Score: 4.02
# Episode 79	Average Score: 4.09
# Episode 80	Average Score: 4.15
# Episode 81	Average Score: 4.23
# Episode 82	Average Score: 4.30
# Episode 83	Average Score: 4.37
# Episode 84	Average Score: 4.46
# Episode 85	Average Score: 4.53
# Episode 86	Average Score: 4.63
# Episode 87	Average Score: 4.73
# Episode 88	Average Score: 4.84
# Episode 89	Average Score: 4.95
# Episode 90	Average Score: 5.07
# Episode 91	Average Score: 5.18
# Episode 92	Average Score: 5.27
# Episode 93	Average Score: 5.39
# Episode 94	Average Score: 5.48
# Episode 95	Average Score: 5.58
# Episode 96	Average Score: 5.72
# Episode 97	Average Score: 5.84
# Episode 98	Average Score: 5.95
# Episode 99	Average Score: 6.08
# Episode 100	Average Score: 6.19
# Episode 101	Average Score: 6.38
# Episode 102	Average Score: 6.57
# Episode 103	Average Score: 6.77
# Episode 104	Average Score: 6.96
# Episode 105	Average Score: 7.15
# Episode 106	Average Score: 7.37
# Episode 107	Average Score: 7.60
# Episode 108	Average Score: 7.81
# Episode 109	Average Score: 8.03
# Episode 110	Average Score: 8.25
# Episode 111	Average Score: 8.46
# Episode 112	Average Score: 8.66
# Episode 113	Average Score: 8.89
# Episode 114	Average Score: 9.10
# Episode 115	Average Score: 9.33
# Episode 116	Average Score: 9.58
# Episode 117	Average Score: 9.81
# Episode 118	Average Score: 10.04
# Episode 119	Average Score: 10.28
# Episode 120	Average Score: 10.52
# Episode 121	Average Score: 10.78
# Episode 122	Average Score: 11.02
# Episode 123	Average Score: 11.31
# Episode 124	Average Score: 11.57
# Episode 125	Average Score: 11.87
# Episode 126	Average Score: 12.15
# Episode 127	Average Score: 12.45
# Episode 128	Average Score: 12.72
# Episode 129	Average Score: 13.02
# Episode 130	Average Score: 13.34
# Episode 131	Average Score: 13.64
# Episode 132	Average Score: 13.98
# Episode 133	Average Score: 14.30
# Episode 134	Average Score: 14.64
# Episode 135	Average Score: 14.99
# Episode 136	Average Score: 15.32
# Episode 137	Average Score: 15.67
# Episode 138	Average Score: 16.01
# Episode 139	Average Score: 16.35
# Episode 140	Average Score: 16.68
# Episode 141	Average Score: 17.01
# Episode 142	Average Score: 17.31
# Episode 143	Average Score: 17.64
# Episode 144	Average Score: 17.97
# Episode 145	Average Score: 18.32
# Episode 146	Average Score: 18.67
# Episode 147	Average Score: 19.01
# Episode 148	Average Score: 19.36
# Episode 149	Average Score: 19.71
# Episode 150	Average Score: 20.06
# Episode 151	Average Score: 20.40
# Episode 152	Average Score: 20.73
# Episode 153	Average Score: 21.06
# Episode 154	Average Score: 21.39
# Episode 155	Average Score: 21.73
# Episode 156	Average Score: 22.05
# Episode 157	Average Score: 22.39
# Episode 158	Average Score: 22.71
# Episode 159	Average Score: 23.03
# Episode 160	Average Score: 23.35
# Episode 161	Average Score: 23.64
# Episode 162	Average Score: 23.94
# Episode 163	Average Score: 24.24
# Episode 164	Average Score: 24.54
# Episode 165	Average Score: 24.85
# Episode 166	Average Score: 25.14
# Episode 167	Average Score: 25.42
# Episode 168	Average Score: 25.71
# Episode 169	Average Score: 26.00
# Episode 170	Average Score: 26.28
# Episode 171	Average Score: 26.56
# Episode 172	Average Score: 26.83
# Episode 173	Average Score: 27.11
# Episode 174	Average Score: 27.40
# Episode 175	Average Score: 27.69
# Episode 176	Average Score: 27.95
# Episode 177	Average Score: 28.19
# Episode 178	Average Score: 28.46
# Episode 179	Average Score: 28.73
# Episode 180	Average Score: 29.00
# Episode 181	Average Score: 29.26
# Episode 182	Average Score: 29.52
# Episode 183	Average Score: 29.74
# Episode 184	Average Score: 30.00
# Episode 185	Average Score: 30.26
#
# Environment solved in 85 episodes!	Average Score: 30.26

# %%
env.close()
